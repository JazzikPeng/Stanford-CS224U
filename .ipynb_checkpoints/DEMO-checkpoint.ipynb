# %% [markdown]
# # Demo
# - Semantic Meaning Extraction

# %%
"""BERT finetuning runner."""

from __future__ import absolute_import, division, print_function, unicode_literals

import argparse
import logging
import os
import random
from io import open

import json
import numpy as np
import torch
import torch.nn as nn
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader, Dataset, RandomSampler
from torch.utils.data.distributed import DistributedSampler
from tqdm import tqdm, trange

from pytorch_transformers.modeling_bert import BertPreTrainedModel, BertConfig, BertModel
from pytorch_transformers.tokenization_bert import BertTokenizer
from pytorch_transformers.optimization import AdamW, WarmupLinearSchedule

logging.basicConfig(format='%(asctime)s - %(levelname)s - %(name)s -   %(message)s',
                    datefmt='%m/%d/%Y %H:%M:%S',
                    level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
class BertForParaphraseDetection(BertPreTrainedModel):
    def __init__(self, config: BertConfig):
        super(BertPreTrainedModel, self).__init__(config)
        self.bert = BertModel(config)
        self.ffn = nn.Linear(config.hidden_size, 2)
        self.apply(self.init_weights)

    def forward(self, input_ids: torch.Tensor, token_type_ids: torch.Tensor, input_mask: torch.Tensor,
                is_paraphrase: torch.Tensor = None):
        outputs = self.bert(input_ids, token_type_ids, input_mask)
        pooled_output = outputs[1]
        paraphrase_score = self.ffn(pooled_output)
        outputs = (paraphrase_score,) + outputs[2:]

        if is_paraphrase is not None:
            loss_fct = CrossEntropyLoss(ignore_index=-1)
            is_paraphrase_loss = loss_fct(paraphrase_score.view(-1, 2), is_paraphrase.view(-1))
            outputs = (is_paraphrase_loss,) + outputs

        return outputs

    def save_pretrained(self, save_directory: str, only_bert: bool = True):
        print('SAVING ONLY BERT...')
        model_to_save = self.bert if only_bert else self

        model_to_save.config.save_pretrained(save_directory)
        output_model_file = os.path.join(save_directory, 'pytorch_model.bin')
        torch.save(model_to_save.state_dict(), output_model_file)


class PPDBDataset(Dataset):
    def __init__(self, corpus_path: str, tokenizer: BertTokenizer, seq_len: int, encoding: str = 'utf-8'):
        self.vocab = tokenizer.vocab
        self.tokenizer = tokenizer
        self.seq_len = seq_len
        self.corpus_path = corpus_path
        self.encoding = encoding

        self.samples = []
        self.sample_counter = 0
        self.count = 0

        with open(corpus_path, mode='r', encoding='utf-8') as fp:
            self.samples = json.load(fp)
            self.count = len(self.samples)

    def __len__(self):
        return self.count

    def __getitem__(self, item):
        curr_id = self.sample_counter
        self.sample_counter += 1

        text1 = self.samples[item]['text1']
        text2 = self.samples[item]['text2']

        if random.random() > 0.5:
            label = 1
        else:
            rand_idx = item
            while rand_idx == item:
                rand_idx = random.randint(0, self.count - 1)

            text2 = self.samples[rand_idx]['text2']
            label = 0

        tokens_a = self.tokenizer.tokenize(text1)
        tokens_b = self.tokenizer.tokenize(text2)
        # print(tokens_a)

        curr_example = PPDBInputExample(curr_id, tokens_a, tokens_b, label)
        curr_features = convert_ppdb_example_to_features(curr_example, self.seq_len, self.tokenizer)
        curr_tensors = (torch.tensor(curr_features.input_ids),
                        torch.tensor(curr_features.input_mask),
                        torch.tensor(curr_features.segment_ids),
                        torch.tensor(curr_features.is_paraphrase))
        return curr_tensors


class PPDBInputExample(object):
    def __init__(self, guid: int, tokens_a: [str], tokens_b: [str], is_paraphrase: int):
        self.guid = guid
        self.tokens_a = tokens_a
        self.tokens_b = tokens_b
        self.is_paraphrase = is_paraphrase


class PPDBInputFeatures(object):
    def __init__(self, input_ids: [int], input_mask: [int], segment_ids: [int], is_paraphrase: int):
        self.input_ids = input_ids
        self.input_mask = input_mask
        self.segment_ids = segment_ids
        self.is_paraphrase = is_paraphrase


def convert_ppdb_example_to_features(example, max_seq_length, tokenizer) -> PPDBInputFeatures:
    tokens_a = example.tokens_a
    tokens_b = example.tokens_b
    # Modifies `tokens_a` and `tokens_b` in place so that the total
    # length is less than the specified length.
    # Account for [CLS], [SEP], [SEP] with "- 3"
    _truncate_seq_pair(tokens_a, tokens_b, max_seq_length - 3)

    tokens = []
    segment_ids = []
    tokens.append("[CLS]")
    segment_ids.append(0)
    for token in tokens_a:
        tokens.append(token)
        segment_ids.append(0)
    tokens.append("[SEP]")
    segment_ids.append(0)

    assert len(tokens_b) > 0
    for token in tokens_b:
        tokens.append(token)
        segment_ids.append(1)
    tokens.append("[SEP]")
    segment_ids.append(1)

    input_ids = tokenizer.convert_tokens_to_ids(tokens)

    # The mask has 1 for real tokens and 0 for padding tokens. Only real
    # tokens are attended to.
    input_mask = [1] * len(input_ids)

    # Zero-pad up to the sequence length.
    while len(input_ids) < max_seq_length:
        input_ids.append(0)
        input_mask.append(0)
        segment_ids.append(0)

    assert len(input_ids) == max_seq_length
    assert len(input_mask) == max_seq_length
    assert len(segment_ids) == max_seq_length

    if example.guid < 5:
        logger.info("*** Example ***")
        logger.info("guid: %s" % example.guid)
        logger.info("tokens: %s" % " ".join(
                [str(x) for x in tokens]))
        logger.info("input_ids: %s" % " ".join([str(x) for x in input_ids]))
        logger.info("input_mask: %s" % " ".join([str(x) for x in input_mask]))
        logger.info(
                "segment_ids: %s" % " ".join([str(x) for x in segment_ids]))

    features = PPDBInputFeatures(input_ids=input_ids,
                             input_mask=input_mask,
                             segment_ids=segment_ids,
                             is_paraphrase=example.is_paraphrase)
    return features

# %%
def main():
    parser = argparse.ArgumentParser()

    ## Required parameters
    parser.add_argument("--train_corpus",
                        default=None,
                        type=str,
                        required=True,
                        help="The input train corpus.")
    parser.add_argument("--bert_model", default=None, type=str, required=True,
                        help="Bert pre-trained model selected in the list: bert-base-uncased, "
                             "bert-large-uncased, bert-base-cased, bert-base-multilingual, bert-base-chinese.")
    parser.add_argument("--output_dir",
                        default=None,
                        type=str,
                        required=True,
                        help="The output directory where the model checkpoints will be written.")

    ## Other parameters
    parser.add_argument("--max_seq_length",
                        default=128,
                        type=int,
                        help="The maximum total input sequence length after WordPiece tokenization. \n"
                             "Sequences longer than this will be truncated, and sequences shorter \n"
                             "than this will be padded.")
    parser.add_argument('--do_debug', action='store_true')
    parser.add_argument("--do_train",
                        action='store_true',
                        help="Whether to run training.")
    parser.add_argument("--train_batch_size",
                        default=32,
                        type=int,
                        help="Total batch size for training.")
    parser.add_argument("--learning_rate",
                        default=3e-5,
                        type=float,
                        help="The initial learning rate for Adam.")
    parser.add_argument("--adam_epsilon",
                        default=1e-8,
                        type=float,
                        help="Epsilon for Adam optimizer.")
    parser.add_argument("--num_train_epochs",
                        default=3.0,
                        type=float,
                        help="Total number of training epochs to perform.")
    parser.add_argument("--warmup_steps",
                        default=0,
                        type=int,
                        help="Linear warmup over warmup_steps.")
    parser.add_argument("--no_cuda",
                        action='store_true',
                        help="Whether not to use CUDA when available")
    parser.add_argument("--on_memory",
                        action='store_true',
                        help="Whether to load train samples into memory or use disk")
    parser.add_argument("--do_lower_case",
                        action='store_true',
                        help="Whether to lower case the input text. True for uncased models, False for cased models.")
    parser.add_argument("--local_rank",
                        type=int,
                        default=-1,
                        help="local_rank for distributed training on gpus")
    parser.add_argument('--seed',
                        type=int,
                        default=42,
                        help="random seed for initialization")
    parser.add_argument('--gradient_accumulation_steps',
                        type=int,
                        default=1,
                        help="Number of updates steps to accumualte before performing a backward/update pass.")
    parser.add_argument('--fp16',
                        action='store_true',
                        help="Whether to use 16-bit float precision instead of 32-bit")
    parser.add_argument('--loss_scale',
                        type = float, default = 0,
                        help = "Loss scaling to improve fp16 numeric stability. Only used when fp16 set to True.\n"
                        "0 (default value): dynamic loss scaling.\n"
                        "Positive power of 2: static loss scaling value.\n")

    args = parser.parse_args()

    if args.local_rank == -1 or args.no_cuda:
        device = torch.device("cuda" if torch.cuda.is_available() and not args.no_cuda else "cpu")
        n_gpu = torch.cuda.device_count()
    else:
        torch.cuda.set_device(args.local_rank)
        device = torch.device("cuda", args.local_rank)
        n_gpu = 1
        # Initializes the distributed backend which will take care of sychronizing nodes/GPUs
        torch.distributed.init_process_group(backend='nccl')
    logger.info("device: {} n_gpu: {}, distributed training: {}, 16-bits training: {}".format(
        device, n_gpu, bool(args.local_rank != -1), args.fp16))

    if args.gradient_accumulation_steps < 1:
        raise ValueError("Invalid gradient_accumulation_steps parameter: {}, should be >= 1".format(
                            args.gradient_accumulation_steps))

    args.train_batch_size = args.train_batch_size // args.gradient_accumulation_steps

    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    if n_gpu > 0:
        torch.cuda.manual_seed_all(args.seed)

    if not args.do_train:
        raise ValueError("Training is currently the only implemented execution option. Please set `do_train`.")

    if os.path.exists(args.output_dir) and os.listdir(args.output_dir):
        raise ValueError("Output directory ({}) already exists and is not empty.".format(args.output_dir))
    if not os.path.exists(args.output_dir) and (args.local_rank == -1 or torch.distributed.get_rank() == 0):
        os.makedirs(args.output_dir)

    tokenizer = BertTokenizer.from_pretrained(args.bert_model, do_lower_case=args.do_lower_case)

    #train_examples = None
    num_train_optimization_steps = None
    if args.do_train:
        print("Loading Train Dataset", args.train_corpus)
        train_dataset = PPDBDataset(args.train_corpus, tokenizer, seq_len=args.max_seq_length)
        num_train_optimization_steps = int(
            len(train_dataset) / args.train_batch_size / args.gradient_accumulation_steps) * args.num_train_epochs
        if args.local_rank != -1:
            num_train_optimization_steps = num_train_optimization_steps // torch.distributed.get_world_size()

    # Prepare model
    model = BertForParaphraseDetection.from_pretrained(args.bert_model)
    if args.fp16:
        model.half()
    model.to(device)
    if args.local_rank != -1:
        try:
            from apex.parallel import DistributedDataParallel as DDP
        except ImportError:
            raise ImportError("Please install apex from https://www.github.com/nvidia/apex to use distributed and fp16 training.")
        model = DDP(model)
    elif n_gpu > 1:
        model = torch.nn.DataParallel(model)

    # Prepare optimizer
    if args.do_train:
        param_optimizer = list(model.named_parameters())
        no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
        optimizer_grouped_parameters = [
            {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
            {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
            ]

        if args.fp16:
            try:
                from apex.optimizers import FP16_Optimizer
                from apex.optimizers import FusedAdam
            except ImportError:
                raise ImportError("Please install apex from https://www.github.com/nvidia/apex to use distributed and fp16 training.")

            optimizer = FusedAdam(optimizer_grouped_parameters,
                                  lr=args.learning_rate,
                                  bias_correction=False,
                                  max_grad_norm=1.0)
            if args.loss_scale == 0:
                optimizer = FP16_Optimizer(optimizer, dynamic_loss_scale=True)
            else:
                optimizer = FP16_Optimizer(optimizer, static_loss_scale=args.loss_scale)

        else:
            optimizer = AdamW(optimizer_grouped_parameters, lr=args.learning_rate, eps=args.adam_epsilon)
        scheduler = WarmupLinearSchedule(optimizer, warmup_steps=args.warmup_steps, t_total=num_train_optimization_steps)

    global_step = 0
    if args.do_train:
        logger.info("***** Running training *****")
        logger.info("  Num examples = %d", len(train_dataset))
        logger.info("  Batch size = %d", args.train_batch_size)
        logger.info("  Num steps = %d", num_train_optimization_steps)

        if args.local_rank == -1:
            train_sampler = RandomSampler(train_dataset)
        else:
            #TODO: check if this works with current data generator from disk that relies on next(file)
            # (it doesn't return item back by index)
            train_sampler = DistributedSampler(train_dataset)
        train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=args.train_batch_size)

        model.train()
        for epoch in trange(int(args.num_train_epochs), desc="Epoch"):
            tr_loss = 0.
            nb_tr_examples, nb_tr_steps = 0, 0
            for step, batch in enumerate(tqdm(train_dataloader, desc="Iteration")):
                if args.do_debug:
                    if nb_tr_steps == 10:
                        break
                batch = tuple(t.to(device) for t in batch)
                input_ids, input_mask, segment_ids, is_paraphrase = batch
                outputs = model(input_ids, segment_ids, input_mask, is_paraphrase)
                loss = outputs[0]
                if n_gpu > 1:
                    loss = loss.mean()
                if args.gradient_accumulation_steps > 1:
                    loss = loss / args.gradient_accumulation_steps
                if args.fp16:
                    optimizer.backward(loss)
                else:
                    loss.backward()
                tr_loss += loss.item()
                nb_tr_examples += input_ids.size(0)
                nb_tr_steps += 1
                if (step + 1) % args.gradient_accumulation_steps == 0:
                    optimizer.step()
                    scheduler.step()  # Update learning rate schedule
                    optimizer.zero_grad()
                    global_step += 1

            logger.info('Total loss at epoch %d: %.5f' % (epoch, tr_loss))
            logger.info('Avrg  loss at epoch %d: %.5f' % (epoch, tr_loss / nb_tr_examples))

        # Save a trained model
        if args.do_train and (args.local_rank == -1 or torch.distributed.get_rank() == 0):
            logger.info("** ** * Saving fine - tuned model ** ** * ")
            model_to_save = model.module if hasattr(model, 'module') else model  # Take care of distributed/parallel training
            model_to_save.save_pretrained(args.output_dir)
            tokenizer.save_pretrained(args.output_dir)


def _truncate_seq_pair(tokens_a, tokens_b, max_length):
    """Truncates a sequence pair in place to the maximum length."""

    # This is a simple heuristic which will always truncate the longer sequence
    # one token at a time. This makes more sense than truncating an equal percent
    # of tokens from each, since if one sequence is very short then each token
    # that's truncated likely contains more information than a longer sequence.
    while True:
        total_length = len(tokens_a) + len(tokens_b)
        if total_length <= max_length:
            break
        if len(tokens_a) > len(tokens_b):
            tokens_a.pop()
        else:
            tokens_b.pop()


def accuracy(out, labels):
    outputs = np.argmax(out, axis=1)
    return np.sum(outputs == labels)


if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] --train_corpus TRAIN_CORPUS --bert_model
#                              BERT_MODEL --output_dir OUTPUT_DIR
#                              [--max_seq_length MAX_SEQ_LENGTH] [--do_debug]
#                              [--do_train]
#                              [--train_batch_size TRAIN_BATCH_SIZE]
#                              [--learning_rate LEARNING_RATE]
#                              [--adam_epsilon ADAM_EPSILON]
#                              [--num_train_epochs NUM_TRAIN_EPOCHS]
#                              [--warmup_steps WARMUP_STEPS] [--no_cuda]
#                              [--on_memory] [--do_lower_case]
#                              [--local_rank LOCAL_RANK] [--seed SEED]
#                              [--gradient_accumulation_steps GRADIENT_ACCUMULATION_STEPS]
#                              [--fp16] [--loss_scale LOSS_SCALE]
# ipykernel_launcher.py: error: the following arguments are required: --train_corpus, --bert_model, --output_dir
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/zhejianpeng/anaconda3/envs/nlu/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
def func(inputs: int) -> float:
    return 1.2

# %%
func(2)
# Out:
# 1.2

# %%
file = "./data/ppdb-2.0-s-all"

# %%
fp = open(file, mode='r', encoding='utf-8')

# %%
for line in fp:
    print(line)
# Out:
# [NN] ||| transplant ||| transplantation ||| PPDB2.0Score=5.24981 PPDB1.0Score=3.295900 -logp(LHS|e1)=0.18597 -logp(LHS|e2)=0.14031 -logp(e1|LHS)=11.83583 -logp(e1|e2)=1.80507 -logp(e1|e2,LHS)=1.46728 -logp(e2|LHS)=11.47593 -logp(e2|e1)=1.49083 -logp(e2|e1,LHS)=1.10738 AGigaSim=0.63439 Abstract=0 Adjacent=0 CharCountDiff=5 CharLogCR=0.40547 ContainsX=0 Equivalence=0.371472 Exclusion=0.000344 GlueRule=0 GoogleNgramSim=0.03067 Identity=0 Independent=0.078161 Lex(e1|e2)=9.64663 Lex(e2|e1)=59.48919 Lexical=1 LogCount=4.67283 MVLSASim=NA Monotonic=1 OtherRelated=0.372735 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.177287 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98821 TargetFormality=0.98464 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=5.00000 WordLogCR=0 ||| 0-0 ||| OtherRelated
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| PPDB2.0Score=5.22098 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.01739 ContainsX=0 Equivalence=0.630569 Exclusion=0.000045 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.257275 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.086572 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.025539 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| PPDB2.0Score=5.21828 PPDB1.0Score=9.463820 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73191 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73191 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.01739 ContainsX=0 Equivalence=0.628765 Exclusion=0.000039 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.258367 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.087278 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.025551 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| PPDB2.0Score=5.21462 PPDB1.0Score=9.463780 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73189 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73189 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.01739 ContainsX=0 Equivalence=0.628765 Exclusion=0.000039 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.258367 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.087278 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.025551 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| PPDB2.0Score=5.21153 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.01739 ContainsX=0 Equivalence=0.628815 Exclusion=0.000039 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.258143 Lex(e1|e2)=61.80281 Lex(e2|e1)=61.80281 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.087507 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.025495 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| PPDB2.0Score=5.19932 PPDB1.0Score=9.463780 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73189 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73189 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.01739 ContainsX=0 Equivalence=0.650092 Exclusion=0.000052 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.245233 Lex(e1|e2)=61.92061 Lex(e2|e1)=61.92061 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.074915 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.029709 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| PPDB2.0Score=5.19752 PPDB1.0Score=9.463780 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73189 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73189 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.523790 Exclusion=0.000022 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.314636 Lex(e1|e2)=61.92059 Lex(e2|e1)=61.92059 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.150490 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.011062 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| PPDB2.0Score=5.19727 PPDB1.0Score=9.463820 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73191 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73191 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.01739 ContainsX=0 Equivalence=0.630569 Exclusion=0.000045 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.257275 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.086572 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.025539 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| PPDB2.0Score=5.19707 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.01739 ContainsX=0 Equivalence=0.630569 Exclusion=0.000045 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.257275 Lex(e1|e2)=61.80281 Lex(e2|e1)=61.80281 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.086572 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.025539 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| PPDB2.0Score=5.19617 PPDB1.0Score=9.463860 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73193 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73193 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.01739 ContainsX=0 Equivalence=0.630569 Exclusion=0.000045 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.257275 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.086572 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.025539 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| PPDB2.0Score=5.19475 PPDB1.0Score=9.463780 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73189 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73189 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.523790 Exclusion=0.000022 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.314636 Lex(e1|e2)=61.92059 Lex(e2|e1)=61.92059 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.150490 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.011062 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| PPDB2.0Score=5.19059 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.01739 ContainsX=0 Equivalence=0.628815 Exclusion=0.000039 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.258143 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.087507 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.025495 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| PPDB2.0Score=5.18955 PPDB1.0Score=9.463780 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73189 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73189 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.01739 ContainsX=0 Equivalence=0.650092 Exclusion=0.000052 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.245233 Lex(e1|e2)=61.92059 Lex(e2|e1)=61.92059 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.074915 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.029709 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| PPDB2.0Score=5.18886 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.01739 ContainsX=0 Equivalence=0.651807 Exclusion=0.000060 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.244296 Lex(e1|e2)=61.92061 Lex(e2|e1)=61.92061 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.074079 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.029757 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| PPDB2.0Score=5.18881 PPDB1.0Score=9.463840 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73192 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73192 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.01739 ContainsX=0 Equivalence=0.651807 Exclusion=0.000060 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.244296 Lex(e1|e2)=61.92059 Lex(e2|e1)=61.92059 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.074079 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.029757 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| PPDB2.0Score=5.18879 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.525850 Exclusion=0.000026 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.316752 Lex(e1|e2)=61.80281 Lex(e2|e1)=61.80281 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.145972 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.011401 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| PPDB2.0Score=5.18507 PPDB1.0Score=9.463860 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73193 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73193 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.525850 Exclusion=0.000026 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.316752 Lex(e1|e2)=61.80281 Lex(e2|e1)=61.80281 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.145972 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.011401 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| PPDB2.0Score=5.17644 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.01739 ContainsX=0 Equivalence=0.629342 Exclusion=0.000047 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.262099 Lex(e1|e2)=61.92061 Lex(e2|e1)=61.92061 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.081823 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.026689 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| PPDB2.0Score=5.17542 PPDB1.0Score=9.463780 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73189 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73189 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.525829 Exclusion=0.000026 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.316635 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.146123 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.011388 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| PPDB2.0Score=5.16757 PPDB1.0Score=9.463820 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73191 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73191 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.527371 Exclusion=0.000030 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.316162 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.145043 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.011394 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| PPDB2.0Score=5.16664 PPDB1.0Score=9.463820 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73191 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73191 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.527371 Exclusion=0.000030 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.316162 Lex(e1|e2)=61.80281 Lex(e2|e1)=61.80281 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.145043 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.011394 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/chinese.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| PPDB2.0Score=5.16655 PPDB1.0Score=9.463760 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73188 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73188 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.525829 Exclusion=0.000026 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.316635 Lex(e1|e2)=61.80281 Lex(e2|e1)=61.80281 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.146123 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.011388 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| PPDB2.0Score=5.16301 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.01739 ContainsX=0 Equivalence=0.630988 Exclusion=0.000055 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.261426 Lex(e1|e2)=61.92061 Lex(e2|e1)=61.92061 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.080745 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.026786 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| PPDB2.0Score=5.15905 PPDB1.0Score=9.463780 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73189 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73189 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.526287 Exclusion=0.000026 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.319309 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.142674 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.011704 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/russian.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| PPDB2.0Score=5.15295 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.526287 Exclusion=0.000026 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.319309 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.142674 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.011704 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| PPDB2.0Score=5.14664 PPDB1.0Score=9.463760 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73188 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73188 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.01739 ContainsX=0 Equivalence=0.629342 Exclusion=0.000047 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.262099 Lex(e1|e2)=61.92059 Lex(e2|e1)=61.92059 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.081823 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.026689 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| PPDB2.0Score=5.14301 PPDB1.0Score=9.463840 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73192 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73192 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.01739 ContainsX=0 Equivalence=0.630988 Exclusion=0.000055 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.261426 Lex(e1|e2)=61.92059 Lex(e2|e1)=61.92059 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.080745 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.026786 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| PPDB2.0Score=5.12783 PPDB1.0Score=9.463840 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73192 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73192 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.529713 Exclusion=0.000036 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.321143 Lex(e1|e2)=61.92059 Lex(e2|e1)=61.92059 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.137094 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.012015 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/spanish.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/english.pdf> ||| PPDB2.0Score=5.11802 PPDB1.0Score=9.463840 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73192 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73192 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.529713 Exclusion=0.000036 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.321143 Lex(e1|e2)=61.92059 Lex(e2|e1)=61.92059 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.137094 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.012015 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| PPDB2.0Score=5.09819 PPDB1.0Score=9.463840 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73192 -logp(e1|e2,LHS)=2.18813 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73192 -logp(e2|e1,LHS)=2.18813 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.528571 Exclusion=0.000032 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.324258 Lex(e1|e2)=61.92059 Lex(e2|e1)=61.92059 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.134798 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.012341 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/arabic.pdf> ||| <www.un.org/depts/dgacm/docs/crp/aconf212crp1/french.pdf> ||| PPDB2.0Score=5.07815 PPDB1.0Score=9.463800 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.67499 -logp(e1|e2)=4.73190 -logp(e1|e2,LHS)=2.18812 -logp(e2|LHS)=15.67499 -logp(e2|e1)=4.73190 -logp(e2|e1,LHS)=2.18812 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.528571 Exclusion=0.000032 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.324258 Lex(e1|e2)=61.92061 Lex(e2|e1)=61.92061 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.134798 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.012341 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| not-for-profit ||| non-profit ||| PPDB2.0Score=5.02735 PPDB1.0Score=2.319990 -logp(LHS|e1)=0.08054 -logp(LHS|e2)=0.07124 -logp(e1|LHS)=10.94878 -logp(e1|e2)=1.59557 -logp(e1|e2,LHS)=1.46765 -logp(e2|LHS)=10.06833 -logp(e2|e1)=0.72442 -logp(e2|e1,LHS)=0.58719 AGigaSim=0.78074 Abstract=0 Adjacent=0 CharCountDiff=-4 CharLogCR=-0.33647 ContainsX=0 Equivalence=0.636297 Exclusion=0.000122 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.019097 Lex(e1|e2)=59.78055 Lex(e2|e1)=59.78055 Lexical=1 LogCount=4.24850 MVLSASim=NA Monotonic=1 OtherRelated=0.189940 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.154544 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99746 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-4.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| mediaeval ||| medieval ||| PPDB2.0Score=4.96470 PPDB1.0Score=3.101030 -logp(LHS|e1)=0.13847 -logp(LHS|e2)=0.04219 -logp(e1|LHS)=13.76792 -logp(e1|e2)=2.25221 -logp(e1|e2,LHS)=2.17436 -logp(e2|LHS)=12.26825 -logp(e2|e1)=0.84882 -logp(e2|e1,LHS)=0.67470 AGigaSim=0.64383 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.11778 ContainsX=0 Equivalence=0.514731 Exclusion=0.000037 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.029582 Lex(e1|e2)=60.74197 Lex(e2|e1)=60.74197 Lexical=1 LogCount=3.17805 MVLSASim=NA Monotonic=1 OtherRelated=0.389530 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.066120 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98867 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| muslims ||| muslim ||| PPDB2.0Score=4.93256 PPDB1.0Score=3.264890 -logp(LHS|e1)=4.41175 -logp(LHS|e2)=1.80858 -logp(e1|LHS)=13.58725 -logp(e1|e2)=1.86710 -logp(e1|e2,LHS)=3.62683 -logp(e2|LHS)=10.51479 -logp(e2|e1)=1.39779 -logp(e2|e1,LHS)=0.55436 AGigaSim=0.32531 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.15415 ContainsX=0 Equivalence=0.423063 Exclusion=0.000001 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.005080 Lex(e1|e2)=60.74197 Lex(e2|e1)=60.74197 Lexical=1 LogCount=3.29584 MVLSASim=NA Monotonic=1 OtherRelated=0.329677 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.242178 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98404 TargetFormality=0.99610 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| school-aged ||| school-age ||| PPDB2.0Score=4.92616 PPDB1.0Score=4.070860 -logp(LHS|e1)=0.14953 -logp(LHS|e2)=0.03190 -logp(e1|LHS)=13.69629 -logp(e1|e2)=2.64918 -logp(e1|e2,LHS)=2.01191 -logp(e2|LHS)=12.35116 -logp(e2|e1)=1.42168 -logp(e2|e1,LHS)=0.66677 AGigaSim=0.80321 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.09531 ContainsX=0 Equivalence=0.379292 Exclusion=0.001314 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.028645 Lex(e1|e2)=61.60215 Lex(e2|e1)=61.60215 Lexical=1 LogCount=2.19722 MVLSASim=NA Monotonic=1 OtherRelated=0.255241 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.335508 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98480 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [NN] ||| modelling ||| modeling ||| PPDB2.0Score=4.91989 PPDB1.0Score=2.848440 -logp(LHS|e1)=0.52765 -logp(LHS|e2)=0.21116 -logp(e1|LHS)=11.08409 -logp(e1|e2)=0.89953 -logp(e1|e2,LHS)=0.82476 -logp(e2|LHS)=11.81697 -logp(e2|e1)=1.94891 -logp(e2|e1,LHS)=1.55764 AGigaSim=0.71573 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.11778 ContainsX=0 Equivalence=0.456994 Exclusion=0.000363 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.138974 Lex(e1|e2)=60.01106 Lex(e2|e1)=60.01106 Lexical=1 LogCount=4.06044 MVLSASim=NA Monotonic=1 OtherRelated=0.237371 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.166298 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98950 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [NN] ||| modeling ||| modelling ||| PPDB2.0Score=4.91710 PPDB1.0Score=2.848400 -logp(LHS|e1)=0.21116 -logp(LHS|e2)=0.52765 -logp(e1|LHS)=11.81697 -logp(e1|e2)=1.94889 -logp(e1|e2,LHS)=1.55762 -logp(e2|LHS)=11.08409 -logp(e2|e1)=0.89951 -logp(e2|e1,LHS)=0.82474 AGigaSim=0.71573 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.11778 ContainsX=0 Equivalence=0.456994 Exclusion=0.000363 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.138974 Lex(e1|e2)=60.01109 Lex(e2|e1)=60.01109 Lexical=1 LogCount=4.06044 MVLSASim=NA Monotonic=1 OtherRelated=0.237371 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.166298 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99266 TargetFormality=0.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| uganda ||| ugandan ||| PPDB2.0Score=4.89635 PPDB1.0Score=4.529370 -logp(LHS|e1)=5.95543 -logp(LHS|e2)=2.37491 -logp(e1|LHS)=14.33999 -logp(e1|e2)=1.37322 -logp(e1|e2,LHS)=2.54078 -logp(e2|LHS)=12.54240 -logp(e2|e1)=3.15615 -logp(e2|e1,LHS)=0.74319 AGigaSim=0.31368 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.15415 ContainsX=0 Equivalence=0.414397 Exclusion=0.000076 GlueRule=0 GoogleNgramSim=0.11022 Identity=0 Independent=0.103656 Lex(e1|e2)=5.08407 Lex(e2|e1)=61.60217 Lexical=1 LogCount=2.19722 MVLSASim=NA Monotonic=1 OtherRelated=0.135802 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.346068 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98673 TargetFormality=0.99667 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| south-eastern ||| south-east ||| PPDB2.0Score=4.89339 PPDB1.0Score=2.937070 -logp(LHS|e1)=0.33068 -logp(LHS|e2)=1.02290 -logp(e1|LHS)=10.54057 -logp(e1|e2)=1.74072 -logp(e1|e2,LHS)=1.04729 -logp(e2|LHS)=10.68842 -logp(e2|e1)=1.19635 -logp(e2|e1,LHS)=1.19514 AGigaSim=0.64383 Abstract=0 Adjacent=0 CharCountDiff=-3 CharLogCR=-0.26236 ContainsX=0 Equivalence=0.423802 Exclusion=0.000347 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.067723 Lex(e1|e2)=59.61803 Lex(e2|e1)=59.61803 Lexical=1 LogCount=4.44265 MVLSASim=NA Monotonic=1 OtherRelated=0.409367 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.098761 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98567 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-3.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| tutsi ||| tutsis ||| PPDB2.0Score=4.87606 PPDB1.0Score=2.829140 -logp(LHS|e1)=1.95942 -logp(LHS|e2)=2.63355 -logp(e1|LHS)=13.95223 -logp(e1|e2)=1.02143 -logp(e1|e2,LHS)=0.67986 -logp(e2|LHS)=15.41263 -logp(e2|e1)=1.80771 -logp(e2|e1,LHS)=2.14026 AGigaSim=0.50354 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.18232 ContainsX=0 Equivalence=0.727783 Exclusion=0.000001 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.003173 Lex(e1|e2)=62.20827 Lex(e2|e1)=62.20827 Lexical=1 LogCount=1.38629 MVLSASim=NA Monotonic=1 OtherRelated=0.039270 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.229773 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99247 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| medium-size ||| medium-sized ||| PPDB2.0Score=4.87257 PPDB1.0Score=5.560000 -logp(LHS|e1)=0.04035 -logp(LHS|e2)=0.01547 -logp(e1|LHS)=12.33095 -logp(e1|e2)=4.75886 -logp(e1|e2,LHS)=4.49439 -logp(e2|LHS)=8.34835 -logp(e2|e1)=0.80114 -logp(e2|e1,LHS)=0.51179 AGigaSim=0.74095 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.08701 ContainsX=0 Equivalence=0.567648 Exclusion=0.000172 GlueRule=0 GoogleNgramSim=0.09191 Identity=0 Independent=0.048954 Lex(e1|e2)=60.21589 Lex(e2|e1)=60.21589 Lexical=1 LogCount=3.82864 MVLSASim=NA Monotonic=1 OtherRelated=0.205114 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.178112 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98747 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| tutsis ||| tutsi ||| PPDB2.0Score=4.85220 PPDB1.0Score=2.829100 -logp(LHS|e1)=2.63355 -logp(LHS|e2)=1.95942 -logp(e1|LHS)=15.41263 -logp(e1|e2)=1.80769 -logp(e1|e2,LHS)=2.14024 -logp(e2|LHS)=13.95223 -logp(e2|e1)=1.02141 -logp(e2|e1,LHS)=0.67984 AGigaSim=0.50354 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.18232 ContainsX=0 Equivalence=0.727783 Exclusion=0.000001 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.003173 Lex(e1|e2)=62.20827 Lex(e2|e1)=62.20827 Lexical=1 LogCount=1.38629 MVLSASim=NA Monotonic=1 OtherRelated=0.039270 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.229773 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99405 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| hi-tech ||| high-tech ||| PPDB2.0Score=4.85040 PPDB1.0Score=3.886470 -logp(LHS|e1)=0.12383 -logp(LHS|e2)=0.06567 -logp(e1|LHS)=11.99364 -logp(e1|e2)=2.68402 -logp(e1|e2,LHS)=2.18108 -logp(e2|LHS)=10.45392 -logp(e2|e1)=1.20245 -logp(e2|e1,LHS)=0.64136 AGigaSim=0.65317 Abstract=0 Adjacent=0 CharCountDiff=2 CharLogCR=0.25131 ContainsX=0 Equivalence=0.532607 Exclusion=0.000704 GlueRule=0 GoogleNgramSim=0.01227 Identity=0 Independent=0.061867 Lex(e1|e2)=60.12886 Lex(e2|e1)=60.12886 Lexical=1 LogCount=3.95124 MVLSASim=NA Monotonic=1 OtherRelated=0.294476 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.110346 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98845 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=2.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| school-age ||| school-aged ||| PPDB2.0Score=4.84292 PPDB1.0Score=4.070930 -logp(LHS|e1)=0.03190 -logp(LHS|e2)=0.14953 -logp(e1|LHS)=12.35116 -logp(e1|e2)=1.42171 -logp(e1|e2,LHS)=0.66678 -logp(e2|LHS)=13.69629 -logp(e2|e1)=2.64922 -logp(e2|e1,LHS)=2.01192 AGigaSim=0.80321 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.09531 ContainsX=0 Equivalence=0.379292 Exclusion=0.001314 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.028645 Lex(e1|e2)=61.60213 Lex(e2|e1)=61.60213 Lexical=1 LogCount=2.19722 MVLSASim=NA Monotonic=1 OtherRelated=0.255241 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.335508 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98014 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [JJ] ||| short-stay ||| short-term ||| PPDB2.0Score=4.84103 PPDB1.0Score=7.443360 -logp(LHS|e1)=0.03055 -logp(LHS|e2)=0.04061 -logp(e1|LHS)=12.76991 -logp(e1|e2)=5.80732 -logp(e1|e2,LHS)=5.57971 -logp(e2|LHS)=8.60870 -logp(e2|e1)=1.63604 -logp(e2|e1,LHS)=1.41849 AGigaSim=0.55557 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.005414 Exclusion=0.002789 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.183991 Lex(e1|e2)=5.26058 Lex(e2|e1)=60.82199 Lexical=1 LogCount=3.09104 MVLSASim=NA Monotonic=1 OtherRelated=0.679367 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.128440 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=1.00000 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| OtherRelated
#
# [JJ] ||| contemptible ||| despicable ||| PPDB2.0Score=4.83864 PPDB1.0Score=5.732290 -logp(LHS|e1)=0.03469 -logp(LHS|e2)=0.01950 -logp(e1|LHS)=13.94039 -logp(e1|e2)=3.97134 -logp(e1|e2,LHS)=3.82730 -logp(e2|LHS)=11.71481 -logp(e2|e1)=1.76095 -logp(e2|e1,LHS)=1.60172 AGigaSim=0.70711 Abstract=0 Adjacent=0 CharCountDiff=-2 CharLogCR=-0.18232 ContainsX=0 Equivalence=0.019063 Exclusion=0.011603 GlueRule=0 GoogleNgramSim=0.07968 Identity=0 Independent=0.039644 Lex(e1|e2)=6.61642 Lex(e2|e1)=61.10968 Lexical=1 LogCount=2.89037 MVLSASim=NA Monotonic=1 OtherRelated=0.792244 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.137446 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-2.00000 WordLogCR=0 ||| 0-0 ||| OtherRelated
#
# [NNS] ||| hundreds ||| thousands ||| PPDB2.0Score=4.83586 PPDB1.0Score=10.733480 -logp(LHS|e1)=0.00283 -logp(LHS|e2)=0.01482 -logp(e1|LHS)=8.69962 -logp(e1|e2)=5.80857 -logp(e1|e2,LHS)=5.54282 -logp(e2|LHS)=7.82796 -logp(e2|e1)=4.92491 -logp(e2|e1,LHS)=4.67116 AGigaSim=0.92851 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.11778 ContainsX=0 Equivalence=0.000457 Exclusion=0.058601 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.491247 Lex(e1|e2)=60.70423 Lex(e2|e1)=60.70423 Lexical=1 LogCount=3.17805 MVLSASim=NA Monotonic=1 OtherRelated=0.032472 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.417223 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98145 TargetFormality=0.98988 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [NNS] ||| thousands ||| hundreds ||| PPDB2.0Score=4.83586 PPDB1.0Score=10.733460 -logp(LHS|e1)=0.01482 -logp(LHS|e2)=0.00283 -logp(e1|LHS)=7.82796 -logp(e1|e2)=4.92490 -logp(e1|e2,LHS)=4.67117 -logp(e2|LHS)=8.69962 -logp(e2|e1)=5.80856 -logp(e2|e1,LHS)=5.54283 AGigaSim=0.92851 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.11778 ContainsX=0 Equivalence=0.000457 Exclusion=0.058601 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.491247 Lex(e1|e2)=60.70421 Lex(e2|e1)=60.70421 Lexical=1 LogCount=3.17805 MVLSASim=NA Monotonic=1 OtherRelated=0.032472 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.417223 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98298 TargetFormality=0.99156 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [NNS] ||| hundred ||| thousands ||| PPDB2.0Score=4.83586 PPDB1.0Score=17.185970 -logp(LHS|e1)=5.31492 -logp(LHS|e2)=0.01482 -logp(e1|LHS)=14.56701 -logp(e1|e2)=9.31246 -logp(e1|e2,LHS)=13.34722 -logp(e2|LHS)=7.82796 -logp(e2|e1)=7.87351 -logp(e2|e1,LHS)=6.60817 AGigaSim=0.14673 Abstract=0 Adjacent=0 CharCountDiff=2 CharLogCR=0.25131 ContainsX=0 Equivalence=0.000456 Exclusion=0.058083 GlueRule=0 GoogleNgramSim=0.11022 Identity=0 Independent=0.490451 Lex(e1|e2)=62.90141 Lex(e2|e1)=62.90141 Lexical=1 LogCount=0 MVLSASim=NA Monotonic=1 OtherRelated=0.031846 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.419165 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98773 TargetFormality=0.83585 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=2.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [NNS] ||| thousands ||| hundred ||| PPDB2.0Score=4.83586 PPDB1.0Score=17.185970 -logp(LHS|e1)=0.01482 -logp(LHS|e2)=5.31492 -logp(e1|LHS)=7.82796 -logp(e1|e2)=7.87351 -logp(e1|e2,LHS)=6.60817 -logp(e2|LHS)=14.56701 -logp(e2|e1)=9.31246 -logp(e2|e1,LHS)=13.34722 AGigaSim=0.14673 Abstract=0 Adjacent=0 CharCountDiff=-2 CharLogCR=-0.25131 ContainsX=0 Equivalence=0.000456 Exclusion=0.058083 GlueRule=0 GoogleNgramSim=0.11022 Identity=0 Independent=0.490451 Lex(e1|e2)=62.90141 Lex(e2|e1)=62.90141 Lexical=1 LogCount=0 MVLSASim=NA Monotonic=1 OtherRelated=0.031846 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.419165 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98298 TargetFormality=0.99156 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-2.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [NNS] ||| hundreds ||| thousand ||| PPDB2.0Score=4.83586 PPDB1.0Score=17.410570 -logp(LHS|e1)=0.00283 -logp(LHS|e2)=4.57478 -logp(e1|LHS)=8.69962 -logp(e1|e2)=8.67388 -logp(e1|e2,LHS)=7.23227 -logp(e2|LHS)=13.33438 -logp(e2|e1)=8.73669 -logp(e2|e1,LHS)=11.86703 AGigaSim=0.26671 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.000457 Exclusion=0.058601 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.491247 Lex(e1|e2)=62.05413 Lex(e2|e1)=62.05413 Lexical=1 LogCount=1.60944 MVLSASim=NA Monotonic=1 OtherRelated=0.032472 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.417223 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98145 TargetFormality=0.98988 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Independent
#
# [NNS] ||| thousand ||| hundreds ||| PPDB2.0Score=4.83586 PPDB1.0Score=17.410590 -logp(LHS|e1)=4.57478 -logp(LHS|e2)=0.00283 -logp(e1|LHS)=13.33438 -logp(e1|e2)=8.73670 -logp(e1|e2,LHS)=11.86701 -logp(e2|LHS)=8.69962 -logp(e2|e1)=8.67389 -logp(e2|e1,LHS)=7.23225 AGigaSim=0.26671 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.000457 Exclusion=0.058601 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.491247 Lex(e1|e2)=62.05413 Lex(e2|e1)=62.05413 Lexical=1 LogCount=1.60944 MVLSASim=NA Monotonic=1 OtherRelated=0.032472 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.417223 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98752 TargetFormality=0.87185 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Independent
#
# [NN] ||| restriction ||| limitations ||| PPDB2.0Score=4.83541 PPDB1.0Score=11.192980 -logp(LHS|e1)=0.04917 -logp(LHS|e2)=6.34742 -logp(e1|LHS)=9.92752 -logp(e1|e2)=5.84716 -logp(e1|e2,LHS)=2.26506 -logp(e2|LHS)=15.72443 -logp(e2|e1)=5.34582 -logp(e2|e1,LHS)=8.06195 AGigaSim=0.48218 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.474116 Exclusion=0.002447 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.127498 Lex(e1|e2)=61.80282 Lex(e2|e1)=61.80282 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.170885 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.225054 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99620 TargetFormality=0.99385 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [NN] ||| restriction ||| limitation ||| PPDB2.0Score=4.83541 PPDB1.0Score=5.846360 -logp(LHS|e1)=0.04917 -logp(LHS|e2)=0.09801 -logp(e1|LHS)=9.92752 -logp(e1|e2)=2.95437 -logp(e1|e2,LHS)=2.08728 -logp(e2|LHS)=9.91397 -logp(e2|e1)=2.89199 -logp(e2|e1,LHS)=2.07373 AGigaSim=0.95331 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.09531 ContainsX=0 Equivalence=0.474116 Exclusion=0.002447 GlueRule=0 GoogleNgramSim=0.16491 Identity=0 Independent=0.127498 Lex(e1|e2)=8.64765 Lex(e2|e1)=58.98941 Lexical=1 LogCount=5.15906 MVLSASim=NA Monotonic=1 OtherRelated=0.170885 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.225054 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99620 TargetFormality=0.99385 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# ...
#
# [NNS] ||| discrepancies ||| disparities ||| PPDB2.0Score=3.88474 PPDB1.0Score=7.230320 -logp(LHS|e1)=0.00243 -logp(LHS|e2)=0.02109 -logp(e1|LHS)=10.29358 -logp(e1|e2)=4.14165 -logp(e1|e2,LHS)=3.70571 -logp(e2|LHS)=9.25926 -logp(e2|e1)=3.08867 -logp(e2|e1,LHS)=2.67139 AGigaSim=0.94953 Abstract=0 Adjacent=0 CharCountDiff=-2 CharLogCR=-0.16705 ContainsX=0 Equivalence=0.300559 Exclusion=0.001577 GlueRule=0 GoogleNgramSim=0.01841 Identity=0 Independent=0.190064 Lex(e1|e2)=59.15588 Lex(e2|e1)=59.15588 Lexical=1 LogCount=4.99721 MVLSASim=NA Monotonic=1 OtherRelated=0.306176 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.201624 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99868 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-2.00000 WordLogCR=0 ||| 0-0 ||| OtherRelated
#
# [VBN] ||| recreated ||| recaptured ||| PPDB2.0Score=3.88470 PPDB1.0Score=19.847280 -logp(LHS|e1)=0.28532 -logp(LHS|e2)=0.46300 -logp(e1|LHS)=13.10093 -logp(e1|e2)=10.32236 -logp(e1|e2,LHS)=9.32563 -logp(e2|LHS)=12.48116 -logp(e2|e1)=9.52492 -logp(e2|e1,LHS)=8.70586 AGigaSim=0.85773 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.10536 ContainsX=0 Equivalence=0.021597 Exclusion=0.015860 GlueRule=0 GoogleNgramSim=0.00614 Identity=0 Independent=0.509652 Lex(e1|e2)=63.30685 Lex(e2|e1)=63.30685 Lexical=1 LogCount=0 MVLSASim=NA Monotonic=1 OtherRelated=0.316611 PhrasePenalty=1 RarityPenalty=0.36788 ReverseEntailment=0.136280 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99666 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [VBZ] ||| views ||| perspective ||| PPDB2.0Score=3.88469 PPDB1.0Score=17.930350 -logp(LHS|e1)=3.61668 -logp(LHS|e2)=8.04758 -logp(e1|LHS)=9.21119 -logp(e1|e2)=8.60526 -logp(e1|e2,LHS)=4.32546 -logp(e2|LHS)=14.36191 -logp(e2|e1)=9.32509 -logp(e2|e1,LHS)=9.47618 AGigaSim=0.56573 Abstract=0 Adjacent=0 CharCountDiff=6 CharLogCR=0.78846 ContainsX=0 Equivalence=0.078575 Exclusion=0.002487 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.450881 Lex(e1|e2)=62.90141 Lex(e2|e1)=62.90141 Lexical=1 LogCount=0 MVLSASim=NA Monotonic=1 OtherRelated=0.347291 PhrasePenalty=1 RarityPenalty=0.01832 ReverseEntailment=0.120767 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99101 TargetFormality=0.99579 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=6.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [NNS] ||| tranquilizers ||| tranquillisers ||| PPDB2.0Score=3.88467 PPDB1.0Score=6.447880 -logp(LHS|e1)=0.12430 -logp(LHS|e2)=0 -logp(e1|LHS)=14.80185 -logp(e1|e2)=2.15065 -logp(e1|e2,LHS)=1.71972 -logp(e2|LHS)=16.82413 -logp(e2|e1)=4.29723 -logp(e2|e1,LHS)=3.74201 AGigaSim=0.57581 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.07411 ContainsX=0 Equivalence=0.372105 Exclusion=0.009506 GlueRule=0 GoogleNgramSim=0.04294 Identity=0 Independent=0.214026 Lex(e1|e2)=62.61372 Lex(e2|e1)=62.61372 Lexical=1 LogCount=0.69315 MVLSASim=NA Monotonic=1 OtherRelated=0.254159 PhrasePenalty=1 RarityPenalty=0.01832 ForwardEntailment=0.150204 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99494 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [VBZ] ||| degenerates ||| deteriorates ||| PPDB2.0Score=3.88467 PPDB1.0Score=11.646990 -logp(LHS|e1)=0.65059 -logp(LHS|e2)=0.09287 -logp(e1|LHS)=14.47969 -logp(e1|e2)=6.80415 -logp(e1|e2,LHS)=5.21526 -logp(e2|LHS)=11.96065 -logp(e2|e1)=4.84284 -logp(e2|e1,LHS)=2.69622 AGigaSim=0.67156 Abstract=0 Adjacent=0 CharCountDiff=1 CharLogCR=0.08701 ContainsX=0 Equivalence=0.079571 Exclusion=0.049424 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.364639 Lex(e1|e2)=63.30685 Lex(e2|e1)=63.30685 Lexical=1 LogCount=0 MVLSASim=NA Monotonic=1 OtherRelated=0.303586 PhrasePenalty=1 RarityPenalty=0.36788 ReverseEntailment=0.202780 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=1.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [VBZ] ||| discover ||| covers ||| PPDB2.0Score=3.88467 PPDB1.0Score=21.484540 -logp(LHS|e1)=4.75161 -logp(LHS|e2)=0.03186 -logp(e1|LHS)=13.19184 -logp(e1|e2)=11.46977 -logp(e1|e2,LHS)=11.08694 -logp(e2|LHS)=7.01709 -logp(e2|e1)=10.01477 -logp(e2|e1,LHS)=4.91220 AGigaSim=0.33689 Abstract=0 Adjacent=0 CharCountDiff=-2 CharLogCR=-0.28768 ContainsX=0 Equivalence=0.001194 Exclusion=0.007706 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.417389 Lex(e1|e2)=62.90141 Lex(e2|e1)=62.90141 Lexical=1 LogCount=0 MVLSASim=NA Monotonic=1 OtherRelated=0.209412 PhrasePenalty=1 RarityPenalty=0.36788 ForwardEntailment=0.364299 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98781 TargetFormality=0.94643 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-2.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [NNS] ||| non-compliances ||| noncompliances ||| PPDB2.0Score=3.88464 PPDB1.0Score=16.257770 -logp(LHS|e1)=0 -logp(LHS|e2)=0 -logp(e1|LHS)=15.12953 -logp(e1|e2)=7.46545 -logp(e1|e2,LHS)=3.32709 -logp(e2|LHS)=16.45641 -logp(e2|e1)=8.79232 -logp(e2|e1,LHS)=4.65396 AGigaSim=0 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.06899 ContainsX=0 Equivalence=0.142277 Exclusion=0.011779 GlueRule=0 GoogleNgramSim=0.06744 Identity=0 Independent=0.387268 Lex(e1|e2)=63.30685 Lex(e2|e1)=63.30685 Lexical=1 LogCount=0 MVLSASim=NA Monotonic=1 OtherRelated=0.185142 PhrasePenalty=1 RarityPenalty=0.36788 ReverseEntailment=0.273533 SourceTerminalsButNoTarget=0 SourceWords=1 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [NN] ||| colloquia ||| symposium ||| PPDB2.0Score=3.88464 PPDB1.0Score=15.276280 -logp(LHS|e1)=0.53693 -logp(LHS|e2)=0.70377 -logp(e1|LHS)=14.97169 -logp(e1|e2)=9.67259 -logp(e1|e2,LHS)=8.31573 -logp(e2|LHS)=11.06963 -logp(e2|e1)=5.60369 -logp(e2|e1,LHS)=4.41367 AGigaSim=0.50354 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.430025 Exclusion=0.003020 GlueRule=0 GoogleNgramSim=0.11022 Identity=0 Independent=0.209607 Lex(e1|e2)=62.39060 Lex(e2|e1)=62.39060 Lexical=1 LogCount=0.69315 MVLSASim=NA Monotonic=1 OtherRelated=0.265786 PhrasePenalty=1 RarityPenalty=0.00005 ReverseEntailment=0.091561 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [NN] ||| colloquium ||| symposium ||| PPDB2.0Score=3.88464 PPDB1.0Score=4.651750 -logp(LHS|e1)=0.72477 -logp(LHS|e2)=0.70377 -logp(e1|LHS)=12.97963 -logp(e1|e2)=3.27038 -logp(e1|e2,LHS)=3.11289 -logp(e2|LHS)=11.06963 -logp(e2|e1)=1.38137 -logp(e2|e1,LHS)=1.20289 AGigaSim=0.95331 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.10536 ContainsX=0 Equivalence=0.429855 Exclusion=0.002655 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.218575 Lex(e1|e2)=61.16684 Lex(e2|e1)=61.16684 Lexical=1 LogCount=2.77259 MVLSASim=NA Monotonic=1 OtherRelated=0.227657 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.121259 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [NN] ||| colloquium ||| symposia ||| PPDB2.0Score=3.88464 PPDB1.0Score=10.914790 -logp(LHS|e1)=0.72477 -logp(LHS|e2)=0.31086 -logp(e1|LHS)=12.97963 -logp(e1|e2)=5.51777 -logp(e1|e2,LHS)=5.11087 -logp(e2|LHS)=12.44497 -logp(e2|e1)=5.39702 -logp(e2|e1,LHS)=4.57620 AGigaSim=0.43862 Abstract=0 Adjacent=0 CharCountDiff=-2 CharLogCR=-0.22314 ContainsX=0 Equivalence=0.430025 Exclusion=0.003020 GlueRule=0 GoogleNgramSim=0.12241 Identity=0 Independent=0.209607 Lex(e1|e2)=61.92061 Lex(e2|e1)=61.92061 Lexical=1 LogCount=1.60944 MVLSASim=NA Monotonic=1 OtherRelated=0.265786 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.091561 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-2.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [NN] ||| colloquia ||| symposia ||| PPDB2.0Score=3.88464 PPDB1.0Score=5.920690 -logp(LHS|e1)=0.53693 -logp(LHS|e2)=0.31086 -logp(e1|LHS)=14.97169 -logp(e1|e2)=4.11067 -logp(e1|e2,LHS)=3.06596 -logp(e2|LHS)=12.44497 -logp(e2|e1)=1.81002 -logp(e2|e1,LHS)=0.53924 AGigaSim=0.71573 Abstract=0 Adjacent=0 CharCountDiff=-1 CharLogCR=-0.11778 ContainsX=0 Equivalence=0.430025 Exclusion=0.003020 GlueRule=0 GoogleNgramSim=0.01227 Identity=0 Independent=0.209607 Lex(e1|e2)=61.92061 Lex(e2|e1)=61.92061 Lexical=1 LogCount=1.79176 MVLSASim=NA Monotonic=1 OtherRelated=0.265786 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.091561 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-1.00000 WordLogCR=0 ||| 0-0 ||| Equivalence
#
# [VBD] ||| facilitated ||| enabled ||| PPDB2.0Score=3.88461 PPDB1.0Score=13.340710 -logp(LHS|e1)=1.12873 -logp(LHS|e2)=1.10201 -logp(e1|LHS)=8.64574 -logp(e1|e2)=6.82784 -logp(e1|e2,LHS)=5.26394 -logp(e2|LHS)=8.30405 -logp(e2|e1)=6.51287 -logp(e2|e1,LHS)=4.92225 AGigaSim=0.54532 Abstract=0 Adjacent=0 CharCountDiff=-4 CharLogCR=-0.45199 ContainsX=0 Equivalence=0.167610 Exclusion=0.003339 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.399240 Lex(e1|e2)=60.53434 Lex(e2|e1)=60.53434 Lexical=1 LogCount=3.36730 MVLSASim=NA Monotonic=1 OtherRelated=0.294411 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.135400 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99938 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-4.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [VBD] ||| facilitating ||| enabled ||| PPDB2.0Score=3.88461 PPDB1.0Score=22.522460 -logp(LHS|e1)=5.62738 -logp(LHS|e2)=1.10201 -logp(e1|LHS)=12.30810 -logp(e1|e2)=11.00057 -logp(e1|e2,LHS)=12.73367 -logp(e2|LHS)=8.30405 -logp(e2|e1)=11.52189 -logp(e2|e1,LHS)=8.72961 AGigaSim=0.14673 Abstract=0 Adjacent=0 CharCountDiff=-5 CharLogCR=-0.53900 ContainsX=0 Equivalence=0.167610 Exclusion=0.003339 GlueRule=0 GoogleNgramSim=0.03067 Identity=0 Independent=0.399240 Lex(e1|e2)=62.90141 Lex(e2|e1)=62.90141 Lexical=1 LogCount=0 MVLSASim=NA Monotonic=1 OtherRelated=0.294411 PhrasePenalty=1 RarityPenalty=0.13534 ReverseEntailment=0.135400 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99872 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=-5.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [VBN] ||| separated ||| differentiated ||| PPDB2.0Score=3.88460 PPDB1.0Score=14.212560 -logp(LHS|e1)=0.36515 -logp(LHS|e2)=1.52600 -logp(e1|LHS)=8.65451 -logp(e1|e2)=6.76063 -logp(e1|e2,LHS)=4.47497 -logp(e2|LHS)=10.50666 -logp(e2|e1)=7.45193 -logp(e2|e1,LHS)=6.32712 AGigaSim=0.43862 Abstract=0 Adjacent=0 CharCountDiff=5 CharLogCR=0.44183 ContainsX=0 Equivalence=0.100804 Exclusion=0.002678 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.537665 Lex(e1|e2)=61.16685 Lex(e2|e1)=61.16685 Lexical=1 LogCount=2.77259 MVLSASim=NA Monotonic=1 OtherRelated=0.089764 PhrasePenalty=1 RarityPenalty=0 ForwardEntailment=0.269090 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.98640 TargetFormality=0.97595 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=5.00000 WordLogCR=0 ||| 0-0 ||| Independent
#
# [VBG] ||| impacting ||| affecting ||| PPDB2.0Score=3.88457 PPDB1.0Score=8.624990 -logp(LHS|e1)=0.06962 -logp(LHS|e2)=0.05961 -logp(e1|LHS)=10.13721 -logp(e1|e2)=6.01821 -logp(e1|e2,LHS)=4.79058 -logp(e2|LHS)=6.71577 -logp(e2|e1)=2.60678 -logp(e2|e1,LHS)=1.36915 AGigaSim=0.90399 Abstract=0 Adjacent=0 CharCountDiff=0 CharLogCR=0 ContainsX=0 Equivalence=0.043724 Exclusion=0.000970 GlueRule=0 GoogleNgramSim=0 Identity=0 Independent=0.352493 Lex(e1|e2)=59.79536 Lex(e2|e1)=59.79536 Lexical=1 LogCount=4.26268 MVLSASim=NA Monotonic=1 OtherRelated=0.420895 PhrasePenalty=1 RarityPenalty=0 ReverseEntailment=0.181917 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99315 TargetFormality=1.00000 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=0 WordLogCR=0 ||| 0-0 ||| OtherRelated
#
# [VBG] ||| impact ||| affecting ||| PPDB2.0Score=3.88457 PPDB1.0Score=20.477670 -logp(LHS|e1)=9.90193 -logp(LHS|e2)=0.05961 -logp(e1|LHS)=14.48174 -logp(e1|e2)=9.20066 -logp(e1|e2,LHS)=11.16261 -logp(e2|LHS)=6.71577 -logp(e2|e1)=11.27701 -logp(e2|e1,LHS)=3.39664 AGigaSim=0.13458 Abstract=0 Adjacent=0 CharCountDiff=3 CharLogCR=0.40547 ContainsX=0 Equivalence=0.043724 Exclusion=0.000970 GlueRule=0 GoogleNgramSim=0.04294 Identity=0 Independent=0.352493 Lex(e1|e2)=63.30685 Lex(e2|e1)=63.30685 Lexical=1 LogCount=0 MVLSASim=NA Monotonic=1 OtherRelated=0.420895 PhrasePenalty=1 RarityPenalty=0.04979 ReverseEntailment=0.181917 SourceTerminalsButNoTarget=0 SourceWords=1 TargetComplexity=0.99474 TargetFormality=0.99785 TargetTerminalsButNoSource=0 TargetWords=1 UnalignedSource=0 UnalignedTarget=0 WordCountDiff=0 WordLenDiff=3.00000 WordLogCR=0 ||| 0-0 ||| OtherRelated
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c946741f1e36> in <module>
#       1 for line in fp:
# ----> 2     print(line)
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
import heapq

# %%
queue = [4,2,3,1]
heapq.heapify(queue)

# %%
heapq.heappop(queue)
# Out:
# 1

# %%
queue
# Out:
# [2, 3, 4]

# %%
queue.pop()
# Out:
# 4
